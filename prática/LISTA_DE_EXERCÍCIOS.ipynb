# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolasllernandes/Algoritmos-e-L-gica-de-Programa-o/blob/main/pr%C3%A1tica/LISTA_DE_EXERC%C3%8DCIOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Adição")

  a = float(input("Insira um número: "))
  b = float(input("Insira um número: "))

  soma = a + b

  print ("Soma/Adição: ", soma)

# %%
print ("Subtração")

a = float(input("Insira um número: "))
b = float(input("Insira um número: "))

subtracao = a - b

print ("Subtração: ", subtracao)

# %%
print ("Multiplicação")

a = float(input("Insira um número: "))
b = float(input("Insira um número: "))

multiplicacao = a * b

print ("Multiplicação: ", multiplicacao)

# %%
print ("Divisão")

a = float(input("Insira um número: "))
b = float(input("Insira um número: "))

divisao = a / b

print ("Divisão: ", divisao)

# %%
print ("Dobro e Triplo")

a = float(input("Insira um número: "))

print ("Dobro: ", a * 2)
print ("Triplo: ", a * 3)

# %%
print ("Antecessor e sucessor")

a = float(input("Insira um número: "))

print("Antecessor: ", a - 1)
print("Sucessor: ", a + 1)

# %%
print ("Área do triângulo")

base = float(input("Insira uma base: "))
altura = float(input("Insira uma altura: "))

print (f"Área do triângulo = {base * altura / 2} metros quadrados ", )

# %%
print ("Perímetro do retângulo")

base = float(input("Insira uma base: "))
altura = float(input("Insira uma altura: "))

print (f"Perímetro do retângulo = {base * 2 + altura * 2} metros")

# %%
print ("Positivo, negativo ou zero")

numero = float(input("Insira um número: "))

if numero > 0:
  print ("Positivo!")

elif numero < 0:
  print ("Negativo!")

else:
  print ("Zero!")

# %%
print ("Par ou Impar")

numero = float (input("Insira um número: "))

if numero % 2 == 0:
  print ("Par!")

else:
  print ("Impar!")

# %%
print ("Maior entre dois números")

a = float(input("Insira um número: "))
b = float(input("Insira um número: "))

if a > b:
  print ("Este é o maior: ", a)

elif b > a:
  print ("Este é o maior: ", b)

else:
  print("Somos todos iguais!")

# %%
print ("Maior entre três números")

a = float(input("Insira um número: "))
b = float(input("Insira um número: "))
c = float(input("Insira um número: "))

maior = a
if (b > maior):
  b = maior
if (c > maior):
  c = maior

print ("Este é o maior: ", maior)

# %%
print ("Eu posso votar?")
idade = int(input("Idade: "))

titulo_eleitor = input("Possui título de eleitor? (sim/não)")
if idade >=16 and titulo_eleitor.lower() == "sim":
  print("Pode votar!")
else:
  print ("Não pode votar!")

# %%
print ("Eu posso dirigir?")

idade = int(input("Idade: "))
cnh = input("Possui CNH? (sim/não)")

if idade >= 18 and cnh.lower() == "sim":
  print ("Pode dirigir!")
else:
  print ("Não pode dirigir!")

# %%
print ("Desconto com compra à vista")

valor = float(input("Insira o valor do produto: "))
desconto = input("Está comprando à vista? (sim/não):")
if desconto.lower() == "sim":
  print ("Desconto aplicado! Total: ", valor * 0.9)
else:
  print ("Total: ", valor)

# %%
print ("Aumento de salário de 15% até 2000 reais")

salario = float(input("Insira seu salário: "))
aumento = input("Deseja aplicar o aumento? (sim/não)")

if salario >= 2000 and aumento.lower() == "Sim":
  aumento == True
  print ("Novo salário: ", salario)
elif salario < 2000 and aumento.lower() == "Sim":
  aumento == True
  print("Novo salário: ", salario * 1.15)
else:
  print ("Novo salário:", salario)

# %%
print ("Número: Intervalo de 10 a 50")

numero = float(input("Insira um número: "))

if numero >=10 and numero <=50:
  print ("Dentro do intervalo!")
else:
  print ("Fora do intervalo!")

# %%
print ("Cadastro senha e validação")

nome = input("Insira um nome: ")
senha = input("Insira uma senha: ")

print ("Login")
nome2 = input ("Insira seu nome: ")
senha2 = input ("Insira sua senha: ")

if nome.lower() == nome2.lower() and senha == senha2:
  print("Seja bem vindo!")
else:
  print ("Credenciais incorretas!")

# %%
print ("Entrada de evento: maioridade + ingresso")


idade = int(input("Qual sua idade?"))
ingresso = input ("Possui ingresso? (sim/nao)")

if idade >=18 and ingresso.lower() == "sim":
  ingresso.lower() == True
  print("Pode entrar!")
else:
  print("Não pode entrar.")

# %%
print ("Calculadora simples: +, -, *, / ")

a = float(input("Insira o primeiro valor: "))
operador = input("selecione o operador (+, -, * ou /): ")
b = float(input("Selecione o segundo valor:"))

if operador == "+":
  print (a, " + ", b, " = ", a + b)
if operador == "-":
  print (a, " - ", b, " = ", a - b)
if operador == "*":
  print (a, " * ", b, " = ", a * b)
if operador == "/":
  print (a, " / ", b, " = ", a / b)

# %%
print ("Prática esportiva: 12 a 17 anos + autorização")

idade = int (input("Insira sua idade: "))
autorizacao = str (input("Tem autorização? (sim/não) ")).lower() == "sim"

if idade >=12 and idade <=17 and autorizacao == True:
  print ("Autorizada a prática esportiva!")
else:
  print ("Não está autorizada a prática esportiva.")

# %%
print ("Está chovendo?")

resposta = input("está chovendo?").lower()

chovendo = resposta

if chovendo == "not" or chovendo == "não":
  chovendo == False
  print ("Saia tranquilo!")

else:
  print ("Não saia de casa sem guarda-chuva!")

# %%
print ("Classificação etária")

idade = int(input("Qual sua idade?"))

if idade < 0:
  print ("Idade inválida!")
elif idade >= 0 and idade <=11:
  print ("Criança")
elif idade >= 12 and idade <=17:
  print ("Adolescente")
elif idade >= 18 and idade <= 59:
  print ("Adulto")
elif idade >=60:
  print ("Idoso")

# %%
print ("Triângulo Equilátero, Isósceles ou Escaleno")

lado1 = float(input("Insira o primeiro lado"))
lado2 = float(input("Insira o segundo lado"))
lado3 = float(input("Insira o terceiro lado"))

if lado1 == lado2 == lado3:
  print ("Equilátero")
elif lado1 == lado2 or lado2 == lado3 or lado1 == lado3:
  print("Isósceles")
elif lado1 != lado2 != lado3:
  print ("Escaleno")
